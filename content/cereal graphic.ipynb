# %% [markdown]
# # Cereal Data
#
# <img src="attachment:dc896c1c-8b28-4ab6-9c1b-36b4a0b98b4e.png" width="250" style="float: right; padding-left: 20px;"/>
#
# We have some data from Kaggle about different cereals.  I started by taking the CSV and exporting the data to lists so that p5.js in a jupyter notebook could deal with it simply.  (The table function seems to be having trouble.)
#
# For our first graphic, we'll plot each cereal along the x axis in alphabetical order, and make our y axis the sodium, and our size the amount of sugar.  Maybe some interesting trends will show up.

# %%
let cereal_data_names = [];
let cereal_data_calories = [];
let cereal_data_protein  = [];
let cereal_data_sodium = [];
let cereal_data_fiber = [];
let cereal_data_sugars = [];
let cereal_data_rating = [];
let my_index=[];

function setup() {
    cereal_data_names = ['100% Bran','100% Natural Bran','All-Bran','All-Bran with Extra Fiber','Almond Delight','Apple Cinnamon Cheerios','Apple Jacks','Basic 4','Bran Chex','Bran Flakes','Cap.n.Crunch','Cheerios','Cinnamon Toast Crunch','Clusters','Cocoa Puffs','Corn Chex','Corn Flakes','Corn Pops','Count Chocula','Cracklin. Oat Bran','Cream of Wheat (Quick)','Crispix','Crispy Wheat & Raisins','Double Chex','Froot Loops','Frosted Flakes','Frosted Mini-Wheats','Fruit & Fibre Dates; Walnuts; and Oats','Fruitful Bran','Fruity Pebbles','Golden Crisp','Golden Grahams','Grape Nuts Flakes','Grape-Nuts','Great Grains Pecan','Honey Graham Ohs','Honey Nut Cheerios','Honey-comb','Just Right Crunchy  Nuggets','Just Right Fruit & Nut','Kix','Life','Lucky Charms','Maypo','Muesli Raisins; Dates; & Almonds','Muesli Raisins; Peaches; & Pecans','Mueslix Crispy Blend','Multi-Grain Cheerios','Nut&Honey Crunch','Nutri-Grain Almond-Raisin','Nutri-grain Wheat','Oatmeal Raisin Crisp','Post Nat. Raisin Bran','Product 19','Puffed Rice','Puffed Wheat','Quaker Oat Squares','Quaker Oatmeal','Raisin Bran','Raisin Nut Bran','Raisin Squares','Rice Chex','Rice Krispies','Shredded Wheat','Shredded Wheat.n.Bran','Shredded Wheat spoon size','Smacks','Special K','Strawberry Fruit Wheats','Total Corn Flakes','Total Raisin Bran','Total Whole Grain','Triples','Trix','Wheat Chex','Wheaties','Wheaties Honey Gold'];
    cereal_data_calories = [70,120,70,50,110,110,110,130,90,90,120,110,120,110,110,110,100,110,110,110,100,110,100,100,110,110,100,120,120,110,100,110,100,110,120,120,110,110,110,140,110,100,110,100,150,150,160,100,120,140,90,130,120,100,50,50,100,100,120,100,90,110,110,80,90,90,110,110,90,110,140,100,110,110,100,100,110];
    cereal_data_protein = [4,3,4,4,2,2,2,3,2,3,1,6,1,3,1,2,2,1,1,3,3,2,2,2,2,1,3,3,3,1,2,1,3,3,3,1,3,1,2,3,2,4,2,4,4,4,3,2,2,3,3,3,3,3,1,2,4,5,3,3,2,1,2,2,3,3,2,6,2,2,3,3,2,1,3,3,2];
    cereal_data_sodium = [130,15,260,140,200,180,125,210,200,210,220,290,210,140,180,280,290,90,180,140,80,220,140,190,125,200,0,160,240,135,45,280,140,170,75,220,250,180,170,170,260,150,180,0,95,150,150,220,190,220,170,170,200,320,0,0,135,0,210,140,0,240,290,0,0,0,70,230,15,200,190,200,250,140,230,200,200];
    cereal_data_fiber = [10,2,9,14,1,1.5,1,2,4,5,0,2,0,2,0,0,1,1,0,4,1,1,2,1,1,1,3,5,5,0,0,0,3,3,3,1,1.5,0,1,2,0,2,0,0,3,3,3,2,0,3,3,1.5,6,1,0,1,2,2.7,5,2.5,2,0,0,3,4,3,1,1,3,0,4,3,0,0,3,3,1];
    cereal_data_sugars = [6,8,5,0,8,10,14,8,6,5,12,1,9,7,13,3,2,12,13,7,0,3,10,5,13,11,7,10,12,12,15,9,5,3,4,11,10,11,6,9,3,6,12,3,11,11,13,6,9,7,2,10,14,3,0,0,6,-1,12,8,6,2,3,0,0,0,15,3,5,3,14,3,3,12,3,3,8];
    cereal_data_rating = [68.402973,33.983679,59.425505,93.704912,34.384843,29.509541,33.174094,37.038562,49.120253,53.313813,18.042851,50.764999,19.823573,40.400208,22.736446,41.445019,45.863324,35.782791,22.396513,40.448772,64.533816,46.895644,36.176196,44.330856,32.207582,31.435973,58.345141,40.917047,41.015492,28.025765,35.252444,23.804043,52.076897,53.371007,45.811716,21.871292,31.072217,28.742414,36.523683,36.471512,39.241114,45.328074,26.734515,54.850917,37.136863,34.139765,30.313351,40.105965,29.924285,40.69232,59.642837,30.450843,37.840594,41.50354,60.756112,63.005645,49.511874,50.828392,39.259197,39.7034,55.333142,41.998933,40.560159,68.235885,74.472949,72.801787,31.230054,53.131324,59.363993,38.839746,28.592785,46.658844,39.106174,27.753301,49.787445,51.592193,36.187559];
    for(let i = 0; i < cereal_data_calories.length; i++) {
        my_index.push(i);
    }
    createCanvas(1000, 400);
    background(220);
    textSize(12);
    noLoop();
}

function draw() {
    fill(color(85, 100, 255));
    for (let j = 0; j < my_index.length; j++) {
        circle(20 + my_index[j] * 5, 350 - cereal_data_sodium[j], cereal_data_calories[j]/5);
    }
}

# %% [markdown]
# ![image.png](attachment:50be789a-f0c5-448b-a1fd-a5c12349f616.png)
#
# This isn't particularly revelatory.  There are a lot of cereals, and they area honstely all over the place with regard to sodium and sugar.  Let's switch from plotting alphabetically, to plotting by calories.  Also, lets have the color determined by the rating.

# %%
let cereal_data_names = [];
let cereal_data_calories = [];
let cereal_data_protein  = [];
let cereal_data_sodium = [];
let cereal_data_fiber = [];
let cereal_data_sugars = [];
let cereal_data_rating = [];
let my_index=[];

function setup() {
    cereal_data_names = ['100% Bran','100% Natural Bran','All-Bran','All-Bran with Extra Fiber','Almond Delight','Apple Cinnamon Cheerios','Apple Jacks','Basic 4','Bran Chex','Bran Flakes','Cap.n.Crunch','Cheerios','Cinnamon Toast Crunch','Clusters','Cocoa Puffs','Corn Chex','Corn Flakes','Corn Pops','Count Chocula','Cracklin. Oat Bran','Cream of Wheat (Quick)','Crispix','Crispy Wheat & Raisins','Double Chex','Froot Loops','Frosted Flakes','Frosted Mini-Wheats','Fruit & Fibre Dates; Walnuts; and Oats','Fruitful Bran','Fruity Pebbles','Golden Crisp','Golden Grahams','Grape Nuts Flakes','Grape-Nuts','Great Grains Pecan','Honey Graham Ohs','Honey Nut Cheerios','Honey-comb','Just Right Crunchy  Nuggets','Just Right Fruit & Nut','Kix','Life','Lucky Charms','Maypo','Muesli Raisins; Dates; & Almonds','Muesli Raisins; Peaches; & Pecans','Mueslix Crispy Blend','Multi-Grain Cheerios','Nut&Honey Crunch','Nutri-Grain Almond-Raisin','Nutri-grain Wheat','Oatmeal Raisin Crisp','Post Nat. Raisin Bran','Product 19','Puffed Rice','Puffed Wheat','Quaker Oat Squares','Quaker Oatmeal','Raisin Bran','Raisin Nut Bran','Raisin Squares','Rice Chex','Rice Krispies','Shredded Wheat','Shredded Wheat.n.Bran','Shredded Wheat spoon size','Smacks','Special K','Strawberry Fruit Wheats','Total Corn Flakes','Total Raisin Bran','Total Whole Grain','Triples','Trix','Wheat Chex','Wheaties','Wheaties Honey Gold'];
    cereal_data_calories = [70,120,70,50,110,110,110,130,90,90,120,110,120,110,110,110,100,110,110,110,100,110,100,100,110,110,100,120,120,110,100,110,100,110,120,120,110,110,110,140,110,100,110,100,150,150,160,100,120,140,90,130,120,100,50,50,100,100,120,100,90,110,110,80,90,90,110,110,90,110,140,100,110,110,100,100,110];
    cereal_data_protein = [4,3,4,4,2,2,2,3,2,3,1,6,1,3,1,2,2,1,1,3,3,2,2,2,2,1,3,3,3,1,2,1,3,3,3,1,3,1,2,3,2,4,2,4,4,4,3,2,2,3,3,3,3,3,1,2,4,5,3,3,2,1,2,2,3,3,2,6,2,2,3,3,2,1,3,3,2];
    cereal_data_sodium = [130,15,260,140,200,180,125,210,200,210,220,290,210,140,180,280,290,90,180,140,80,220,140,190,125,200,0,160,240,135,45,280,140,170,75,220,250,180,170,170,260,150,180,0,95,150,150,220,190,220,170,170,200,320,0,0,135,0,210,140,0,240,290,0,0,0,70,230,15,200,190,200,250,140,230,200,200];
    cereal_data_fiber = [10,2,9,14,1,1.5,1,2,4,5,0,2,0,2,0,0,1,1,0,4,1,1,2,1,1,1,3,5,5,0,0,0,3,3,3,1,1.5,0,1,2,0,2,0,0,3,3,3,2,0,3,3,1.5,6,1,0,1,2,2.7,5,2.5,2,0,0,3,4,3,1,1,3,0,4,3,0,0,3,3,1];
    cereal_data_sugars = [6,8,5,0,8,10,14,8,6,5,12,1,9,7,13,3,2,12,13,7,0,3,10,5,13,11,7,10,12,12,15,9,5,3,4,11,10,11,6,9,3,6,12,3,11,11,13,6,9,7,2,10,14,3,0,0,6,-1,12,8,6,2,3,0,0,0,15,3,5,3,14,3,3,12,3,3,8];
    cereal_data_rating = [68.402973,33.983679,59.425505,93.704912,34.384843,29.509541,33.174094,37.038562,49.120253,53.313813,18.042851,50.764999,19.823573,40.400208,22.736446,41.445019,45.863324,35.782791,22.396513,40.448772,64.533816,46.895644,36.176196,44.330856,32.207582,31.435973,58.345141,40.917047,41.015492,28.025765,35.252444,23.804043,52.076897,53.371007,45.811716,21.871292,31.072217,28.742414,36.523683,36.471512,39.241114,45.328074,26.734515,54.850917,37.136863,34.139765,30.313351,40.105965,29.924285,40.69232,59.642837,30.450843,37.840594,41.50354,60.756112,63.005645,49.511874,50.828392,39.259197,39.7034,55.333142,41.998933,40.560159,68.235885,74.472949,72.801787,31.230054,53.131324,59.363993,38.839746,28.592785,46.658844,39.106174,27.753301,49.787445,51.592193,36.187559];
    for(let i = 0; i < cereal_data_calories.length; i++) {
        my_index.push(i);
    }
    createCanvas(1000, 400);
    background(220);
    textSize(12);
    noLoop();
}

function draw() {
    for (let j = 0; j < my_index.length; j++) {
        fill(color(0, 100, cereal_data_rating[j]*4));
        circle(cereal_data_calories[j]*5, 350 - cereal_data_sodium[j], cereal_data_sugars[j]* 3);
    }
}

# %% [markdown]
# ![image.png](attachment:9417aebf-e1ab-4665-9009-58fc1e93e354.png)
#
# There seems to be a correlation between rating and the calories, but not as close of a relationship to sodium or sugar.  Right now this is a kind of fun graphic, but it isn't legible without any lables or title.

# %%
let cereal_data_names = [];
let cereal_data_calories = [];
let cereal_data_protein  = [];
let cereal_data_sodium = [];
let cereal_data_fiber = [];
let cereal_data_sugars = [];
let cereal_data_rating = [];
let my_index=[];
let cereals;

function setup() {
    cereal_data_names = ['100% Bran','100% Natural Bran','All-Bran','All-Bran with Extra Fiber','Almond Delight','Apple Cinnamon Cheerios','Apple Jacks','Basic 4','Bran Chex','Bran Flakes','Cap.n.Crunch','Cheerios','Cinnamon Toast Crunch','Clusters','Cocoa Puffs','Corn Chex','Corn Flakes','Corn Pops','Count Chocula','Cracklin. Oat Bran','Cream of Wheat (Quick)','Crispix','Crispy Wheat & Raisins','Double Chex','Froot Loops','Frosted Flakes','Frosted Mini-Wheats','Fruit & Fibre Dates; Walnuts; and Oats','Fruitful Bran','Fruity Pebbles','Golden Crisp','Golden Grahams','Grape Nuts Flakes','Grape-Nuts','Great Grains Pecan','Honey Graham Ohs','Honey Nut Cheerios','Honey-comb','Just Right Crunchy  Nuggets','Just Right Fruit & Nut','Kix','Life','Lucky Charms','Maypo','Muesli Raisins; Dates; & Almonds','Muesli Raisins; Peaches; & Pecans','Mueslix Crispy Blend','Multi-Grain Cheerios','Nut&Honey Crunch','Nutri-Grain Almond-Raisin','Nutri-grain Wheat','Oatmeal Raisin Crisp','Post Nat. Raisin Bran','Product 19','Puffed Rice','Puffed Wheat','Quaker Oat Squares','Quaker Oatmeal','Raisin Bran','Raisin Nut Bran','Raisin Squares','Rice Chex','Rice Krispies','Shredded Wheat','Shredded Wheat.n.Bran','Shredded Wheat spoon size','Smacks','Special K','Strawberry Fruit Wheats','Total Corn Flakes','Total Raisin Bran','Total Whole Grain','Triples','Trix','Wheat Chex','Wheaties','Wheaties Honey Gold'];
    cereal_data_calories = [70,120,70,50,110,110,110,130,90,90,120,110,120,110,110,110,100,110,110,110,100,110,100,100,110,110,100,120,120,110,100,110,100,110,120,120,110,110,110,140,110,100,110,100,150,150,160,100,120,140,90,130,120,100,50,50,100,100,120,100,90,110,110,80,90,90,110,110,90,110,140,100,110,110,100,100,110];
    cereal_data_protein = [4,3,4,4,2,2,2,3,2,3,1,6,1,3,1,2,2,1,1,3,3,2,2,2,2,1,3,3,3,1,2,1,3,3,3,1,3,1,2,3,2,4,2,4,4,4,3,2,2,3,3,3,3,3,1,2,4,5,3,3,2,1,2,2,3,3,2,6,2,2,3,3,2,1,3,3,2];
    cereal_data_sodium = [130,15,260,140,200,180,125,210,200,210,220,290,210,140,180,280,290,90,180,140,80,220,140,190,125,200,0,160,240,135,45,280,140,170,75,220,250,180,170,170,260,150,180,0,95,150,150,220,190,220,170,170,200,320,0,0,135,0,210,140,0,240,290,0,0,0,70,230,15,200,190,200,250,140,230,200,200];
    cereal_data_fiber = [10,2,9,14,1,1.5,1,2,4,5,0,2,0,2,0,0,1,1,0,4,1,1,2,1,1,1,3,5,5,0,0,0,3,3,3,1,1.5,0,1,2,0,2,0,0,3,3,3,2,0,3,3,1.5,6,1,0,1,2,2.7,5,2.5,2,0,0,3,4,3,1,1,3,0,4,3,0,0,3,3,1];
    cereal_data_sugars = [6,8,5,0,8,10,14,8,6,5,12,1,9,7,13,3,2,12,13,7,0,3,10,5,13,11,7,10,12,12,15,9,5,3,4,11,10,11,6,9,3,6,12,3,11,11,13,6,9,7,2,10,14,3,0,0,6,-1,12,8,6,2,3,0,0,0,15,3,5,3,14,3,3,12,3,3,8];
    cereal_data_rating = [68.402973,33.983679,59.425505,93.704912,34.384843,29.509541,33.174094,37.038562,49.120253,53.313813,18.042851,50.764999,19.823573,40.400208,22.736446,41.445019,45.863324,35.782791,22.396513,40.448772,64.533816,46.895644,36.176196,44.330856,32.207582,31.435973,58.345141,40.917047,41.015492,28.025765,35.252444,23.804043,52.076897,53.371007,45.811716,21.871292,31.072217,28.742414,36.523683,36.471512,39.241114,45.328074,26.734515,54.850917,37.136863,34.139765,30.313351,40.105965,29.924285,40.69232,59.642837,30.450843,37.840594,41.50354,60.756112,63.005645,49.511874,50.828392,39.259197,39.7034,55.333142,41.998933,40.560159,68.235885,74.472949,72.801787,31.230054,53.131324,59.363993,38.839746,28.592785,46.658844,39.106174,27.753301,49.787445,51.592193,36.187559];
    for(let i = 0; i < cereal_data_calories.length; i++) {
        my_index.push(i);
    }
    createCanvas(1000, 400);
    background(220);
    textSize(20);
}
//This draws our buttons to change colors.
function drawInterface() {
    textSize(20);
    fill("yellow"); //sodium button
    rect(30, 50, 120, 50, 20);
    fill("black");
    text("Protein", 40, 80);
    fill("magenta"); //fiber button
    rect(30, 150, 120, 50, 20);
    fill("black");
    text("Fiber", 40, 180);
    fill("green"); //rating button
    rect(30, 250, 120, 50, 20);
    fill("white");
    text("Rating", 40, 280);
}
//This draws the axis on the sides of the visualization
function drawAxis() {
    textSize(15);
    fill("black");
    text("50", 250, 380);
    text("150", 250 + 500, 380);
    line(250, 360, 250 + 500, 360);
    text("Calories", 450, 380);
    line(250, 360, 250, 50);
    text("0", 220, 360);
    text("290", 220, 50);
    text("Na", 220, 200);
}

function draw() {
    background(220);
    drawInterface();
    drawAxis();
    cereals = "";
    textSize(17);
    for (let j = 0; j < my_index.length; j++) {
        fill(color(0, 100, cereal_data_rating[j]*4));
        //Show Protein Levels
        if (abs(mouseX - 75) < 120 && abs(mouseY - 75) < 50) {
            fill(color(cereal_data_protein[j]*35, cereal_data_protein[j]*35, 0));
        }
        //Show Fiber Levels
        if (abs(mouseX - 75) < 120 && abs(mouseY - 175) < 50) {
            fill(color(cereal_data_fiber[j]*35, 0, cereal_data_fiber[j]*35));
        }
        //Show Ratings
        if (abs(mouseX - 75) < 120 && abs(mouseY - 275) < 50) {
            fill(color(0, cereal_data_rating[j]*3, 0));
        }
        if (abs(mouseX - (cereal_data_calories[j]*5)) < 4 && abs(mouseY - (350 - cereal_data_sodium[j])) < 4) {
            cereals += cereal_data_names[j];
            fill("yellow")
        }
        circle(cereal_data_calories[j]*5, 350 - cereal_data_sodium[j], cereal_data_sugars[j]*3);
        
        
    }
    fill("black");
    text(cereals, mouseX, mouseY);
}

# %%
%show
