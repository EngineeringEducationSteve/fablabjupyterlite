# %% [markdown]
# # Graphics and Math
#
# We can use Jupyter Notebooks for data analysis and to make powerful data visualizations.
#
# For instance we can look at some useful data:
#
# |Hamburgers | Distance | Drive Time | Basic Hamburger Price | Quality of Hamburger |
# |---|---|---|---|---|
# |In-N-Out (Manteca) | 11.1 mi    | 19 min   |  3.69 |   10   |
# |In-N-Out (Modesto) |  11.6 mi   | 25 min   | 3.69  |    10     |
# |Chick-Fil-A (Manteca) | 11 mi  | 18 min  | 5.79 |  9      |
# |Chick-Fil-A (Lathrop) | 20 mi  | 32 min  | 5.79 |   9     |
# |Carl's Junior (Ripon) | 11.5 mi | 18 min  | 7.04|   8       |
# |The Habit (Manteca) |  9 mi    | 24 min  | 7.49 |      5    |
# |The Habit (Modesto) |  11.2 mi    | 18 min  | 7.49 |    5      |
# |Sonic (Modesto) |  9.5 mi    |  27 min    | 5.89 |       2    |

# %%
let burgers, distance, drive_time, price, quality;

function setup() {
    createCanvas(1000, 400);
    burgers = ["In-N-Out (Manteca)", "In-N-Out (Modesto)", "Chick-Fil-A (Manteca)", "Chick-Fil-A (Lathrop)", "Carl's Junior (Ripon)", "The Habit (Manteca)", "The Habit (Modesto)", "Sonic (Modesto)"];
    distance = [11.1, 11.6, 11, 20, 11.5, 9, 11.2, 9.5];
    drive_time = [19, 25, 18, 32, 18, 24, 18, 27];
    price = [3.69, 3.69, 5.79, 5.79, 7.04, 7.49, 7.49, 5.89];
    quality = [10, 10, 9, 9, 8, 5, 5, 2];
    textSize(15);
}

function drawPoint(my_name, my_icon, my_x, my_y, my_size, my_color) {
    textSize(my_size * 15);
    my_color = 50 + round(my_color) * 20;
    fill(color(255 - my_color, my_color, my_color));
    rect(10 * my_x, 350 - 8 * my_y - 20, my_size * 25, my_size * 5);
    fill(color(0, 0, 0));
    text(my_icon, 10 * my_x + 25, 350 - 8 * my_y - 20);
    textSize(my_size * 5 /2);
    text(my_name, 10 * my_x + 5, 345 - 8 * my_y);
}

function draw() {
    clear();
    drawPoint(burgers[0], "🍔", 5 * 1, drive_time[0], price[0], quality[0]);
    drawPoint(burgers[1], "🍔", 5 * 3, drive_time[1], price[1], quality[1]);
    drawPoint(burgers[2], "🐔", 5 * 5, drive_time[2], price[2], quality[2]);
    drawPoint(burgers[3], "🐔", 5 * 7, drive_time[3], price[3], quality[3]);
    drawPoint(burgers[4], "🍔", 5 * 9, drive_time[4], price[4], quality[4]);
    drawPoint(burgers[5], "🍔", 5 * 11, drive_time[5], price[5], quality[5]);
    drawPoint(burgers[6], "🍔", 5 * 13, drive_time[6], price[6], quality[6]);
    drawPoint(burgers[7], "🍔", 5 * 15, drive_time[7], price[7], quality[7]);
}

# %% [markdown]
# We can use math to define shapes and create images.  In fact there is some math in any image you see on a screen.  The types of math depends on the image. For instance, many things that look like drawings are vector graphics, defined by a function that draws a line.  3D graphics are also, lines, but they are defined with more dimensions.  For instance, consider a function like y = f(x) = x<sup>2</sup>.  A 3D function would look more like z = f(x, y) = x<sup>2</sup> + y<sup>2</sup>. <br>
# We can draw 4 simple rectangles with the code below.  Can you write a few lines of code to change them into an "E"?

# %%
function setup() {
  createCanvas(400, 400);
}

function draw() {
    clear();
    background(220);
    fill(color("red"));
    rect(20, 150, 50, 50);
    fill(color("green"));
    rect(100, 150, 50, 50);
    fill(color("blue"));
    rect(180, 150, 50, 50);
    fill (color("purple"));
    rect (260, 150, 50, 50);
}

# %%
%show

# %% [markdown]
# We can move from 2D to 3D with TinkerCAD.  We can can code simple shapes using mathematical definitions.
#
# One quick example is this cylinder with a 3D spiral.  Notice that we have two basic objects and a loop that repeats the second object changing the angle and z location in each iteration.
#
# ![Screenshot 2025-04-03 at 10.59.28 AM.png](attachment:88def92a-cd0c-4635-a326-130ddf53e14b.png)
#
# You can modify or print it from <a href="https://www.tinkercad.com/codeblocks/hkwLtSPxOwm-spiral-example">here</a>.
#
# Another shape we can define is this cougar.  Notice again we have used simple shapes, just more this time.
#
# ![Screenshot 2025-04-03 at 11.25.34 AM.png](attachment:9c49ee1e-5f7c-49a6-aae9-617fe89bb841.png)
#
# You can modify or print this shape from <a href="https://www.tinkercad.com/codeblocks/3EdfWk8SJzt-cougar?sharecode=0oMURGFEAhC_-na6c0nuuY2YBRa42N-j5g1xPdylPmY">here</a>.
